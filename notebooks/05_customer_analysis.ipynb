# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)


sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)
plt.rcParams["font.size"] = 12

# %%
ecom_data_df = pd.read_parquet("../data/olist_ecom.parquet")

# %%
ecom_data_df.sample(3)
# Out:
#       index                       customer_id  \
# 5606   5606  c81be24f970cdf800017108e48d4b098
# 6797   6797  bce717de943b9b16756121e882a9fb9c
# 4607   4607  676dc133e16631c5a4329fa53d7bfe3d
#
#                     customer_unique_id  customer_zip_code_prefix  \
# 5606  6a3660b7885a554b070eaffa53f19687                   11015.0
# 6797  e0c3aaad51e0c7b6339ea1b589de52fb                    8215.0
# 4607  5a864ed43d66c0df7fb841732847b343                   78510.0
#
#      customer_city customer_state                          order_id  \
# 5606        santos             SP  b8bfa12431142333a0c84802f9529d87
# 6797     sao paulo             SP  70fdb98b88f9b34c5e8fce09e093c747
# 4607           N/A             MT  28b877013b30a7b9edf8ce22fe59087f
#
#      order_status order_purchase_timestamp   order_approved_at  \
# 5606    delivered      2018-01-21 09:13:13 2018-01-20 09:08:37
# 6797      shipped      2017-05-29 22:00:32 2017-05-29 22:15:18
# 4607    delivered      2018-05-01 08:18:37 2018-05-03 10:57:07
#
#      order_delivered_carrier_date order_delivered_customer_date  \
# 5606          2018-01-23 14:19:36           2018-01-31 00:23:01
# 6797          2017-05-30 14:18:54           2017-06-06 16:40:51
# 4607          2018-05-03 13:25:00           2018-05-16 14:03:29
#
#      order_estimated_delivery_date  payment_sequential payment_type  \
# 5606                    2018-02-09                 1.0       boleto
# 6797                    2017-06-19                 1.0  credit_card
# 4607                           NaT                 1.0  credit_card
#
#       payment_installments  payment_value  order_item_id  \
# 5606                   1.0         300.15            3.0
# 6797                   8.0         169.00            1.0
# 4607                   3.0         321.67            1.0
#
#                             product_id                         seller_id  \
# 5606  765a8070ece0f1383d0f5faf913dfb9b  218d46b86c1881d022bce9c68a7d4b15
# 6797  d986e4bd747ca20b348abcd013cd1303  440dd6ab244315c632130ecfb63827b1
# 4607  af144ed65466a16118af719a57053c95  e333046ce6517bd8bb510291d44f0130
#
#      shipping_limit_date  price  freight_value product_category_name  \
# 5606 2018-01-25 09:08:37   81.0           0.00         esporte_lazer
# 6797 2017-06-04 22:15:18  154.9          14.10         esporte_lazer
# 4607 2018-05-09 10:57:07  289.0          32.67            cool_stuff
#
#       product_name_lenght  product_description_lenght  product_photos_qty  \
# 5606                 44.0                      1186.0                 1.0
# 6797                 59.0                       938.0                 4.0
# 4607                 52.0                      1060.0                 1.0
#
#       product_weight_g  product_length_cm  product_height_cm  \
# 5606             683.0               20.0               19.0
# 6797            1200.0               80.0               14.0
# 4607            1815.0               29.0               21.0
#
#       product_width_cm  time_to_approve  time_to_carrier  shipping_time  \
# 5606              19.0        -1.003194         3.215961       7.419039
# 6797              14.0         0.010255         0.669167       7.098576
# 4607              23.0         2.110069         0.102697      13.026725
#
#       total_delivery_time  delivery_vs_estimate  Frequency  Monetary  Recency  \
# 5606             9.631806             -8.984016          1    600.30      232
# 6797             7.777998            -12.304965          1    169.00      468
# 4607            15.239491                   NaN          1    321.67      132
#
#       R_score  F_score  M_score RFM_score_string  RFM_score_composite  \
# 5606        3        1        5              315                    9
# 6797        1        1        4              114                    6
# 4607        4        1        5              415                   10
#
#                                RFM_segment
# 5606   Single Buyers (Moderate R & High M)
# 6797  Single Buyers (Hibernating & High M)
# 4607   Single Buyers (High Value & Recent)

# %% [markdown]
# ## Descriptive Statistics for Recency, Frequency, Monetary

# %%
ecom_data_df[["Recency", "Frequency", "Monetary"]].describe()
# Out:
#            Recency    Frequency      Monetary
# count  7475.000000  7475.000000   7475.000000
# mean    251.635987     1.005351    250.755609
# std     153.046402     0.072961    642.292232
# min       1.000000     1.000000      0.000000
# 25%     126.000000     1.000000     60.415000
# 50%     235.000000     1.000000    111.890000
# 75%     358.000000     1.000000    213.575000
# max     705.000000     2.000000  11200.200000

# %%
plt.figure(figsize=(10, 8))
# Plot Recency
sns.histplot(ecom_data_df["Recency"], bins=30, kde=True)
plt.title("Recency Distribution (Days since last purchase)")
plt.xlabel("Recency (Day)")
plt.ylabel("Number of Customers")
plt.tight_layout()
plt.show()

# %%
# Monetary Plot (using a log scale due to the highly skewed distribution)
plt.figure(figsize=(10, 8))
sns.histplot(
    ecom_data_df[ecom_data_df["Monetary"] > 0]["Monetary"],
    bins=30,
    kde=True,
    log_scale=True,
)
plt.title("Monetary Distribution (Spend Value) - Log Scale")
plt.xlabel("Monetary (Log Scale)")
plt.ylabel("Number of Customers")

plt.tight_layout()
plt.show()

# %%
# Plot Frequency
plt.figure(figsize=(10, 8))
sns.countplot(x="Frequency", data=ecom_data_df)
plt.title("Distribution Frequency (Number of Purchases)")
plt.xlabel("Frequency")
plt.ylabel("Number of Customers")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##  Distribution Frequency in column `Frequency`

# %%
print(ecom_data_df["Frequency"].value_counts(normalize=True) * 100)
# Out:
# Frequency
# 1    99.464883
# 2     0.535117
# Name: proportion, dtype: float64

# %%
frequency_distribution = ecom_data_df["Frequency"].value_counts(normalize=True) * 100
frequency_distribution = frequency_distribution.sort_values(ascending=False)

# %%
plt.figure(figsize=(10, 8))
sns.barplot(
    x=frequency_distribution.values,
    y=frequency_distribution.index.astype(str),
)
plt.title("Percentage Distribution of Customer Purchase Frequency", fontsize=16)
plt.xlabel("Percentage of Customers (%)", fontsize=12)
plt.ylabel("Frequency of Purchases (Number of Purchases)", fontsize=12)

plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Distribution RFM Segment

# %%
print(ecom_data_df["RFM_segment"].value_counts(normalize=True) * 100)
# Out:
# RFM_segment
# Single Buyers (Recent & Moderate/Low M)         22.929766
# Single Buyers (Moderate R & Moderate/Low M)     22.327759
# Single Buyers (Moderate R & High M)             18.220736
# Single Buyers (High Value & Recent)             16.240803
# Single Buyers (Hibernating & Moderate/Low M)    11.464883
# Single Buyers (Hibernating & High M)             8.280936
# Repeat Buyers (Champions)                        0.200669
# Repeat Buyers (Less Recent & High M)             0.187291
# Repeat Buyers (Less Recent & Moderate/Low M)     0.107023
# Repeat Buyers (Recent & Moderate/Low M)          0.040134
# Name: proportion, dtype: float64

# %%
rfm_avg_per_segment = (
    ecom_data_df.groupby("RFM_segment")[["Recency", "Frequency", "Monetary"]]
    .mean()
    .reset_index()
)
rfm_avg_per_segment_melted = rfm_avg_per_segment.melt(
    id_vars="RFM_segment", var_name="Metric", value_name="Average Value"
)

# %%
plt.figure(figsize=(10, 8))
sns.barplot(
    x="Average Value",
    y="RFM_segment",
    hue="Metric",
    data=rfm_avg_per_segment_melted,
    palette="muted",
)
plt.title("Average Recency, Frequency, Monetary per RFM Segment")
plt.xlabel("Average value")
plt.ylabel("RFM Segment")
plt.legend(title="Metrics")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## RFM Metrics Avarage per Segment

# %%
display(
    ecom_data_df.groupby("RFM_segment")[["Recency", "Frequency", "Monetary"]].mean()
)
# Out:
#                                                  Recency  Frequency  \
# RFM_segment
# Repeat Buyers (Champions)                     115.533333        2.0
# Repeat Buyers (Less Recent & High M)          271.714286        2.0
# Repeat Buyers (Less Recent & Moderate/Low M)  332.750000        2.0
# Repeat Buyers (Recent & Moderate/Low M)        91.000000        2.0
# Single Buyers (Hibernating & High M)          488.846527        1.0
# Single Buyers (Hibernating & Moderate/Low M)  486.824971        1.0
# Single Buyers (High Value & Recent)           101.682043        1.0
# Single Buyers (Moderate R & High M)           280.687225        1.0
# Single Buyers (Moderate R & Moderate/Low M)   283.026363        1.0
# Single Buyers (Recent & Moderate/Low M)       101.862894        1.0
#
#                                                 Monetary
# RFM_segment
# Repeat Buyers (Champions)                     385.926000
# Repeat Buyers (Less Recent & High M)          363.770000
# Repeat Buyers (Less Recent & Moderate/Low M)   94.585000
# Repeat Buyers (Recent & Moderate/Low M)       106.250000
# Single Buyers (Hibernating & High M)          445.729451
# Single Buyers (Hibernating & Moderate/Low M)   67.271517
# Single Buyers (High Value & Recent)           416.436837
# Single Buyers (Moderate R & High M)           584.038194
# Single Buyers (Moderate R & Moderate/Low M)    65.853625
# Single Buyers (Recent & Moderate/Low M)        68.820782

# %%
delivery_metrics_avg = (
    ecom_data_df.groupby("RFM_segment")[["total_delivery_time", "delivery_vs_estimate"]]
    .mean()
    .reset_index()
)
delivery_metrics_avg_melted = delivery_metrics_avg.melt(
    id_vars="RFM_segment", var_name="Metric", value_name="Average Days"
)
delivery_metrics_avg_melted["Metric"] = delivery_metrics_avg_melted[
    "Metric"
].str.replace("_", " ")

# %%
plt.figure(figsize=(14, 8))
sns.barplot(
    x="Average Days",
    y="RFM_segment",
    hue="Metric",
    data=delivery_metrics_avg_melted,
    palette="muted",
)
plt.title("Average Total Delivery Time and Performance vs. Estimates per RFM Segment")
plt.xlabel("Average Days")
plt.ylabel("RFM segment")
plt.legend(title="Shipping Metrics")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## More Detailed Customer Profiles per Segment

# %% [markdown]
# function to create top column based on column `RFM_segment`

# %%
def top_segment(df, col, top_n=5):
    """
    Analyzes the top N occurrences of a specific attribute within each RFM segment.

    Args:
    dataframe (pd.DataFrame): The input DataFrame containing 'RFM_segment'
                                and the 'attribute_column'.
    attribute_column (str): The name of the column to analyze (e.g., 'product_category_name').
    top_n (int): The number of top occurrences to display for each segment.

    Returns:
    None: Prints the analysis results directly.
    """
    print(f"top {top_n} {col.replace("_"," ").title()} per segment")
    
    # Calculate value counts per segment for the given attribute
    attribute_counts_per_segment = df.groupby('RFM_segment')[col].value_counts(normalize=True) * 100
    
    # Iterate through unique segments in the DataFrame
    for segment in df['RFM_segment'].unique():
        print(f"\n--- Segment: {segment} ---")
        
        # Check if the segment exists in the calculated counts
        if segment in attribute_counts_per_segment.index.get_level_values(0):
            # Access and print the top N for the current segment
            print(attribute_counts_per_segment.loc[segment].head(top_n))
        else:
            print("No data available for this segment.")

# %%
top_segment(ecom_data_df, "product_category_name")
# Out:
# top 5 Product Category Name per segment
#
# --- Segment: Single Buyers (Recent & Moderate/Low M) ---
# product_category_name
# beleza_saude              10.501750
# cama_mesa_banho            9.276546
# esporte_lazer              7.001167
# utilidades_domesticas      6.826138
# informatica_acessorios     6.242707
# Name: proportion, dtype: float64
#
# --- Segment: Single Buyers (Moderate R & Moderate/Low M) ---
# product_category_name
# cama_mesa_banho     10.665069
# esporte_lazer       10.065908
# beleza_saude         7.789095
# unknown_category     7.369682
# telefonia            6.171360
# Name: proportion, dtype: float64
#
# --- Segment: Single Buyers (Hibernating & Moderate/Low M) ---
# product_category_name
# unknown_category    10.501750
# cama_mesa_banho      9.684947
# moveis_decoracao     9.334889
# esporte_lazer        8.401400
# beleza_saude         7.817970
# Name: proportion, dtype: float64
#
# --- Segment: Single Buyers (Hibernating & High M) ---
# product_category_name
# cama_mesa_banho          9.531502
# moveis_decoracao         9.046850
# unknown_category         6.946688
# esporte_lazer            6.785137
# utilidades_domesticas    6.138934
# Name: proportion, dtype: float64
#
# --- Segment: Single Buyers (Moderate R & High M) ---
# product_category_name
# relogios_presentes    8.370044
# unknown_category      8.370044
# cama_mesa_banho       8.296623
# esporte_lazer         7.856094
# beleza_saude          7.048458
# Name: proportion, dtype: float64
#
# --- Segment: Single Buyers (High Value & Recent) ---
# product_category_name
# beleza_saude             10.543657
# relogios_presentes       10.296540
# moveis_decoracao          8.896211
# utilidades_domesticas     6.919275
# cama_mesa_banho           5.930807
# Name: proportion, dtype: float64
#
# --- Segment: Repeat Buyers (Less Recent & High M) ---
# product_category_name
# moveis_decoracao    21.428571
# beleza_saude        14.285714
# eletrodomesticos    14.285714
# brinquedos           7.142857
# cama_mesa_banho      7.142857
# Name: proportion, dtype: float64
#
# --- Segment: Repeat Buyers (Less Recent & Moderate/Low M) ---
# product_category_name
# eletrodomesticos               50.0
# cama_mesa_banho                25.0
# fashion_bolsas_e_acessorios    25.0
# Name: proportion, dtype: float64
#
# --- Segment: Repeat Buyers (Champions) ---
# product_category_name
# beleza_saude             26.666667
# cama_mesa_banho          13.333333
# eletrodomesticos         13.333333
# utilidades_domesticas    13.333333
# brinquedos                6.666667
# Name: proportion, dtype: float64
#
# --- Segment: Repeat Buyers (Recent & Moderate/Low M) ---
# product_category_name
# telefonia           66.666667
# unknown_category    33.333333
# Name: proportion, dtype: float64

# %%
top_segment(ecom_data_df, "customer_state")
# Out:
# top 5 Customer State per segment
#
# --- Segment: Single Buyers (Recent & Moderate/Low M) ---
# customer_state
# SP     45.507585
# RJ     10.910152
# MG     10.326721
# N/A     6.417736
# PR      4.492415
# Name: proportion, dtype: float64
#
# --- Segment: Single Buyers (Moderate R & Moderate/Low M) ---
# customer_state
# SP     42.840024
# RJ     12.222888
# MG     11.084482
# N/A     5.632115
# RS      5.272618
# Name: proportion, dtype: float64
#
# --- Segment: Single Buyers (Hibernating & Moderate/Low M) ---
# customer_state
# SP     39.906651
# RJ     12.252042
# MG     10.268378
# N/A     6.767795
# PR      5.600933
# Name: proportion, dtype: float64
#
# --- Segment: Single Buyers (Hibernating & High M) ---
# customer_state
# SP     31.825525
# RJ     14.378029
# MG     12.116317
# N/A     6.623586
# BA      4.846527
# Name: proportion, dtype: float64
#
# --- Segment: Single Buyers (Moderate R & High M) ---
# customer_state
# SP     32.305433
# RJ     14.464023
# MG     12.041116
# N/A     5.580029
# RS      5.066079
# Name: proportion, dtype: float64
#
# --- Segment: Single Buyers (High Value & Recent) ---
# customer_state
# SP     40.032949
# RJ     11.367381
# MG     11.037891
# N/A     5.766063
# PR      4.859967
# Name: proportion, dtype: float64
#
# --- Segment: Repeat Buyers (Less Recent & High M) ---
# customer_state
# SP    28.571429
# BA    14.285714
# GO    14.285714
# MG    14.285714
# MS    14.285714
# Name: proportion, dtype: float64
#
# --- Segment: Repeat Buyers (Less Recent & Moderate/Low M) ---
# customer_state
# MG     25.0
# PR     25.0
# SP     25.0
# N/A    12.5
# RJ     12.5
# Name: proportion, dtype: float64
#
# --- Segment: Repeat Buyers (Champions) ---
# customer_state
# BA    20.000000
# SP    20.000000
# DF    13.333333
# MG    13.333333
# PE    13.333333
# Name: proportion, dtype: float64
#
# --- Segment: Repeat Buyers (Recent & Moderate/Low M) ---
# customer_state
# BA    100.0
# Name: proportion, dtype: float64

# %%
top_segment(ecom_data_df, "payment_type")
# Out:
# top 5 Payment Type per segment
#
# --- Segment: Single Buyers (Recent & Moderate/Low M) ---
# payment_type
# credit_card    72.287048
# boleto         20.186698
# voucher         5.600933
# debit_card      1.925321
# Name: proportion, dtype: float64
#
# --- Segment: Single Buyers (Moderate R & Moderate/Low M) ---
# payment_type
# credit_card    71.899341
# boleto         18.873577
# voucher         8.388256
# debit_card      0.838826
# Name: proportion, dtype: float64
#
# --- Segment: Single Buyers (Hibernating & Moderate/Low M) ---
# payment_type
# credit_card    71.761960
# boleto         18.669778
# voucher         8.401400
# debit_card      1.166861
# Name: proportion, dtype: float64
#
# --- Segment: Single Buyers (Hibernating & High M) ---
# payment_type
# credit_card    74.474960
# boleto         19.063005
# voucher         6.138934
# debit_card      0.323102
# Name: proportion, dtype: float64
#
# --- Segment: Single Buyers (Moderate R & High M) ---
# payment_type
# credit_card    75.550661
# boleto         20.190896
# voucher         3.450808
# debit_card      0.807636
# Name: proportion, dtype: float64
#
# --- Segment: Single Buyers (High Value & Recent) ---
# payment_type
# credit_card    78.253707
# boleto         16.309720
# voucher         3.459638
# debit_card      1.976936
# Name: proportion, dtype: float64
#
# --- Segment: Repeat Buyers (Less Recent & High M) ---
# payment_type
# credit_card    100.0
# Name: proportion, dtype: float64
#
# --- Segment: Repeat Buyers (Less Recent & Moderate/Low M) ---
# payment_type
# credit_card    87.5
# voucher        12.5
# Name: proportion, dtype: float64
#
# --- Segment: Repeat Buyers (Champions) ---
# payment_type
# credit_card    100.0
# Name: proportion, dtype: float64
#
# --- Segment: Repeat Buyers (Recent & Moderate/Low M) ---
# payment_type
# voucher    100.0
# Name: proportion, dtype: float64

# %%
key_segments = [
    "Single Buyers (High Value & Recent)",
    "Single Buyers (Moderate R & High M)",
    "Single Buyers (Hibernating & High M)",
    "Repeat Buyers (Champions)",
]

# %% [markdown]
# ### Top 5 Category Product

# %%
plt.figure(figsize=(16, 12))
for i, segment in enumerate(key_segments):
    plt.subplot(2, 2, i + 1)
    segment_df = ecom_data_df[ecom_data_df["RFM_segment"] == segment]
    if not segment_df.empty:
        top_categories = (
            segment_df["product_category_name"].value_counts(normalize=True).head(5)
            * 100
        )
        sns.barplot(x=top_categories.values, y=top_categories.index)
        plt.title(f"Top 5 Product Categories: {segment}", fontsize=12)
        plt.xlabel("Percentage (%)", fontsize=10)
        plt.ylabel("Product Categories", fontsize=10)
    else:
        plt.title(f"There is no data for this segment: {segment}", fontsize=12)
        plt.text(
            0.5,
            0.5,
            "No data available",
            horizontalalignment="center",
            verticalalignment="center",
            transform=plt.gca().transAxes,
        )

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 5 Payment Type

# %%
plt.figure(figsize=(16, 12))
for i, segment in enumerate(key_segments):
    plt.subplot(2, 2, i + 1)
    segment_df = ecom_data_df[ecom_data_df["RFM_segment"] == segment]
    if not segment_df.empty:
        top_categories = (
            segment_df["payment_type"].value_counts(normalize=True).head(5) * 100
        )
        sns.barplot(x=top_categories.values, y=top_categories.index)
        plt.title(f"Top 5 payment type: {segment}", fontsize=12)
        plt.xlabel("Percentage (%)", fontsize=10)
        plt.ylabel("payment type", fontsize=10)
    else:
        plt.title(f"There is no data for this segment: {segment}", fontsize=12)
        plt.text(
            0.5,
            0.5,
            "No data available",
            horizontalalignment="center",
            verticalalignment="center",
            transform=plt.gca().transAxes,
        )

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 5 Country State

# %%
plt.figure(figsize=(16, 12))
for i, segment in enumerate(key_segments):
    plt.subplot(2, 2, i + 1)
    segment_df = ecom_data_df[ecom_data_df["RFM_segment"] == segment]
    if not segment_df.empty:
        top_categories = (
            segment_df["customer_state"].value_counts(normalize=True).head(5) * 100
        )
        sns.barplot(x=top_categories.values, y=top_categories.index)
        plt.title(f"Top 5 States: {segment}", fontsize=12)
        plt.xlabel("Percentage (%)", fontsize=10)
        plt.ylabel("States", fontsize=10)
    else:
        plt.title(f"There is no data for this segment: {segment}", fontsize=12)
        plt.text(
            0.5,
            0.5,
            "No data available",
            horizontalalignment="center",
            verticalalignment="center",
            transform=plt.gca().transAxes,
        )

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Average Delivery Performance Metrics per Segment

# %%
delivery_cols = [
    "time_to_approve",
    "time_to_carrier",
    "shipping_time",
    "total_delivery_time",
    "delivery_vs_estimate",
]

# check the columns
if all(col in ecom_data_df.columns for col in delivery_cols):
    display(ecom_data_df.groupby("RFM_segment")[delivery_cols].mean())
else:
    print(
        "Some delivery columns were not found. Make sure the column names are exactly the same"
    )
# Out:
#                                               time_to_approve  \
# RFM_segment
# Repeat Buyers (Champions)                           -1.579353
# Repeat Buyers (Less Recent & High M)                -0.726541
# Repeat Buyers (Less Recent & Moderate/Low M)        -0.092224
# Repeat Buyers (Recent & Moderate/Low M)             -0.464684
# Single Buyers (Hibernating & High M)                -1.007320
# Single Buyers (Hibernating & Moderate/Low M)        -0.503844
# Single Buyers (High Value & Recent)                 -0.386856
# Single Buyers (Moderate R & High M)                 -1.124425
# Single Buyers (Moderate R & Moderate/Low M)         -0.716261
# Single Buyers (Recent & Moderate/Low M)             -0.056916
#
#                                               time_to_carrier  shipping_time  \
# RFM_segment
# Repeat Buyers (Champions)                            4.161752      11.213184
# Repeat Buyers (Less Recent & High M)                 2.939307      10.607511
# Repeat Buyers (Less Recent & Moderate/Low M)         2.304990      11.376256
# Repeat Buyers (Recent & Moderate/Low M)              2.677450       8.444001
# Single Buyers (Hibernating & High M)                 3.319382       9.257268
# Single Buyers (Hibernating & Moderate/Low M)         2.745928       8.696467
# Single Buyers (High Value & Recent)                  2.666814       8.443508
# Single Buyers (Moderate R & High M)                  3.468689      10.847895
# Single Buyers (Moderate R & Moderate/Low M)          3.009198      10.253108
# Single Buyers (Recent & Moderate/Low M)              2.296238       7.660200
#
#                                               total_delivery_time  \
# RFM_segment
# Repeat Buyers (Champions)                               13.795583
# Repeat Buyers (Less Recent & High M)                    12.820277
# Repeat Buyers (Less Recent & Moderate/Low M)            13.589022
# Repeat Buyers (Recent & Moderate/Low M)                 10.656767
# Single Buyers (Hibernating & High M)                    11.541799
# Single Buyers (Hibernating & Moderate/Low M)            10.931662
# Single Buyers (High Value & Recent)                     10.719086
# Single Buyers (Moderate R & High M)                     13.180541
# Single Buyers (Moderate R & Moderate/Low M)             12.533100
# Single Buyers (Recent & Moderate/Low M)                  9.898975
#
#                                               delivery_vs_estimate
# RFM_segment
# Repeat Buyers (Champions)                               -12.086819
# Repeat Buyers (Less Recent & High M)                    -12.230647
# Repeat Buyers (Less Recent & Moderate/Low M)             -7.162870
# Repeat Buyers (Recent & Moderate/Low M)                 -22.619502
# Single Buyers (Hibernating & High M)                    -15.063888
# Single Buyers (Hibernating & Moderate/Low M)            -13.791240
# Single Buyers (High Value & Recent)                     -12.612150
# Single Buyers (Moderate R & High M)                     -10.231591
# Single Buyers (Moderate R & Moderate/Low M)              -9.956529
# Single Buyers (Recent & Moderate/Low M)                 -10.790220
